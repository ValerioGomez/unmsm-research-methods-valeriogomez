# %% [markdown]
# <a href="https://colab.research.google.com/github/ValerioGomez/unmsm-research-methods-valeriogomez/blob/main/modelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hola")
# Out:
# hola
