# %% [markdown]
# <a href="https://colab.research.google.com/github/ValerioGomez/unmsm-research-methods-valeriogomez/blob/main/EKJEMPLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi")
# Out:
# Hi

# %%
print("Hi 2")
# Out:
# Hi 2
